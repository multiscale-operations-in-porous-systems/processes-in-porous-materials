# %% [markdown]
# ```{code-cell} python
# :tags: [remove-cell]
#
# pip install numpy matplotlib jupyterquiz, scipy.stats
# ```

# %% [markdown]
# # Single phase flow in porous materials
# ## Theory
# We have covered several definitions and concepts related to single phase flow in porous materials. In this section you find questions that test your understanding of the theory.
#
# ### Question 1 - Porosity and void ratio 1
# The most fundamental of all porous material related properties is that of porosity $\phi$. It is defined as the ratio between volume of voids to that of the bulk material:
#
# :::{math}
# :label: por-eq-1
# \begin{aligned}
# \phi &= \frac{V_{void}}{V_{bulk}} \\
# V_{bulk} &= V_{pores}+V_{matrix}
# \end{aligned}
# :::
# A related concept is that of the void ratio, which is more common in geotechnical applications.
# :::{math}
# :label: por-eq-2
#
# e = \frac{V_{void}}{V_{matrix}}
#
# :::

# %%
from jupyterquiz import display_quiz
display_quiz("../quiz/2_SPF_PM/q1.json", shuffle_answers=True)
# Out:
# <div id="QXZqQsQpFGch" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #QXZqQsQpFGch {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# ::::{warning} Attention
#
# The reason this question is a multiple choice question is that we consider the mathematics involved to obtain the solution as trivial. This means we expect you to be able to derive the relation between ϕ and e without any problem - also during an exam. If you were not able to do this, please look again at equations @por-eq-1 and @por-eq-2.
#
# :::{tip} Solution Question 1
# :class: dropdown
#
# Use equations @por-eq-1 and @por-eq-2. For instance, start by writing expressions for $V_{\text{void}}$.
#
# From equation @por-eq-1:
# \begin{equation*}
# V_{\text{void}} = \phi V_{\text{void}} + \phi V_{\text{matrix}}
# \end{equation*}
# From equation @por-eq-2:
# \begin{equation*}
# V_{\text{void}} = e V_{\text{matrix}}
# \end{equation*}
# Equate both expressions:
# \begin{equation*}
# \phi V_{\text{void}} + \phi V_{\text{matrix}} = e V_{\text{matrix}}
# \end{equation*}
# Divide by $V_{\text{matrix}}$:
# \begin{equation*}
# \phi \frac{V_{\text{void}}}{V_{\text{matrix}}} + \phi = e
# \end{equation*}
# Note that $\frac{V_{\text{void}}}{V_{\text{matrix}}}$ is the definition of $e$, so:
# \begin{equation*}
# \phi \cdot e + \phi = e
# \end{equation*}
# This can be reorganized to:
# \begin{equation*}
# \phi(1 + e) = e \implies \phi = \frac{e}{1 + e}
# \end{equation*}
# :::
#
#
# ::::

# %% [markdown]
# ### Question 2 - Porosity and void ratio 2
# The void ratio, denoted by $e$, is a dimensionless soil property. Let $e$ vary from 0 to 3 in increments of 0.1.
# Using the relationship between porosity ($\phi$) and void ratio ($e$) you found in the previous question:
# 1. Create an array of values for $e$.
# 2. Calculate the corresponding values of $\phi$.
# 3. Plot $\phi$ versus $e$.
# 4. Label the axes and add a title.

# %%
# Use python code to plot the relationship between \phi and e in this cell
import matplotlib.pyplot as plt
import numpy as np

# 1. Create an array of values for e (from 0 to 3 with steps of 0.1)
#e = ...

# 2. Calculate the corresponding values of \phi
#phi = ...

# 3. Plot \phi versus e
#plt.plot(...)

# 4. Label the axes and add a title
#plt.xlabel(...)
#plt.ylabel(...)
#plt.title(...)
#plt.grid(...)
#plt.show()

# %% [markdown]
# ::::{tip} Solution Question 2
# :class: dropdown
#
# :::{figure} ../figures/2_SPF_PM/q2_Solution.png
# :label: fig-q2sol
# :alt: Graph showing the relationship between ϕ and e.
# :width: 800px
# :align: center
#
# Graph showing the relationship between ϕ and e.
# :::
#
# ::::
# ### Question 3 - Porosity and void ratio 3

# %%
from jupyterquiz import display_quiz
display_quiz("../quiz/2_SPF_PM/q3.json")
# Out:
# <div id="wvBDrEwkJFVd" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #wvBDrEwkJFVd {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# :::{hint} Hints Question 3
# :class: dropdown
#
# Use equations @por-eq-1 and @por-eq-2.
# * for a) Think about what has been given in the problem: what is the mass of all solids (the matrix)? What is their volume? If you know that, you should be able to find the volume that all voids occupy.
# * for b) Once you solved a) you should be able to solve this using the definition in @por-eq-2.
# * for c) $\theta = \frac{V_w}{V_t}$ So well done! You looked for the definition in a book! Later in this course you will encounter it again, together with the term 'Saturation'
# * for d) Completely saturated means a saturation of 1, i.e. all pores are full of one single fluid phase. You can assume the density of water to be a $1000 \text{kg/m}^3$. Does it have to be water? No, but in this exercise it does. See the intro to the question.
# :::
#
# :::{tip} Solution Question 3
# :class: dropdown
# #### a. Porosity ($\phi$)
#
# * **Volume of solids ($V_s$):**
# The volume occupied by the solid matrix is calculated from the dry mass and the solid density:
# \begin{equation*}
# V_s = \frac{m_s}{\rho_s} = \frac{1318.3\text{ g}}{2.70\text{ g/cm}^3} \approx 488.26\text{ cm}^3
# \end{equation*}
# * **Volume of voids ($V_v$):**
# The total volume of the voids (pores filled with whatever fluid) is the difference between the total volume and the solid volume:
# \begin{equation*}
# V_v = V - V_s = 728.2\text{ cm}^3 - 488.26\text{ cm}^3 \approx 239.94\text{ cm}^3
# \end{equation*}
# * **Porosity ($\phi$):**
# Porosity is defined as the ratio of void volume to the total volume:
# \begin{equation*}
# \phi = \frac{V_v}{V} = \frac{239.94\text{ cm}^3}{728.2\text{ cm}^3} \approx 0.3295
# \end{equation*}
# #### b. Void ratio ($e$)
#
# The void ratio is defined as the ratio of void volume to the solid volume:
# \begin{equation*}
# e = \frac{V_v}{V_s} = \frac{239.94\text{ cm}^3}{488.26\text{ cm}^3} \approx 0.4914
# \end{equation*}
# #### c. Volumetric water content ($\theta$)
# The volumetric water content is defined as the ratio of the volume of water ($V_w$) to the total volume ($V$).
#
# * **Mass of water ($m_w$):**
#
# \begin{equation*}
# m_w = m - m_s = 1523.6\text{ g} - 1318.3\text{ g} = 205.3\text{ g}
# \end{equation*}
# * **Volume of water ($V_w$):** *(Assuming $\rho_w = 1.0\text{ g/cm}^3$)*
#
# \begin{equation*}
#   V_w = \frac{m_w}{\rho_w} = 205.3\text{ cm}^3
# \end{equation*}
# * **Volumetric water content ($\theta$):**
# \begin{equation*}
#   \theta = \frac{V_w}{V} = \frac{205.3\text{ cm}^3}{728.2\text{ cm}^3} \approx 0.2819
# \end{equation*}
#
# #### d. Total saturated weight ($m_{\text{sat}}$)
#
# When completely saturated, all the void space ($V_v$) is entirely filled with water.
#
# * **Saturated mass of the lab sample ($m_{\text{sat}}$):**
# \begin{equation*}
#   m_{\text{sat}} = m_s + (V_v \times \rho_w) = 1318.3\text{ g} + (239.94\text{ cm}^3 \times 1.0\text{ g/cm}^3) = 1558.24\text{ g}
# \end{equation*}
# :::

# %% [markdown]
# ### Question 4 - Porosity, specific surface area and tortuosity in a simple cubic packing
# When considering a matrix made of ideal particles (spheres) there are several ways to pack them together, see @fig-packing. Each of the packings has its own unit cell and its typical porosity value. You can calculate those using simple geometry. <br>
# N.B. this type of image is also used in chemistry to indicate the structure of crystalline solids. The spheres would represent atoms in that case. Here we should think of them as grains (so at a length scale much greater than atoms).
# N.B.2 there are more ways to pack the spheres together, e.g. hexagonal forms. An overview can be found in Table 10.56 on [this website](https://openstax.org/books/chemistry-2e/pages/10-6-lattice-structures-in-crystalline-solids?query=unit%20cells%20of%20metals&target=%7B%22type%22%3A%22search%22%2C%22index%22%3A0%7D#CNX_Chem_10_06_CubUntCll)
#
# :::{figure} ../figures/2_SPF_PM/Lattice_packing.png
# :label: fig-packing
# :alt: Image showing various types of packing.
# :width: 600px
# :align: center
#
# Image showing Simple Cubic Packing, Body-centered Cubic Packing and Face-centered Cubic Packing. By: Rice University [Openstax](https://openstax.org/books/chemistry-2e/pages/10-6-lattice-structures-in-crystalline-solids?query=unit%20cells%20of%20metals&target=%7B%22type%22%3A%22search%22%2C%22index%22%3A0%7D#CNX_Chem_10_06_CubUntCll) [CC BY NC SA](https://creativecommons.org/licenses/by-nc-sa/4.0/)
# :::
#
# :::{figure} ../figures/2_SPF_PM/unit_cell_packing.png
# :label: fig-unit
# :alt: unit cell for Simple Cubic Packing.
# :width: 500px
# :align: center
#
# Image showing a unit cell for Simple Cubic Packing. By [Johannes Schneider - Own work](https://commons.wikimedia.org/w/index.php?curid=41537389), [CC BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0/deed.en) Consider the length of one side of the cube to be $a$, and the radius of a sphere as $R$.
#
# :::
#
# You can use both @fig-packing and @fig-unit for the following exercise.

# %%
import json
from jupyterquiz import display_quiz

display_quiz("../quiz/2_SPF_PM/q_packing_of_spheres.json")
# Out:
# <div id="bvmPdYzNodru" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #bvmPdYzNodru {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# ::::{hint} Hint Question 4
# :class: dropdown
# * You need radius $R$ and the length of one side of the cube $a$ (unit cell). Can you see that their relation is $a=2R$? Use this to describe $V_{total}$ and $V_{void}$.
# * Similar idea but now for surface area. Specific surface area just means 'per unit volume'.
# ::::
# :::{tip} Solution Question 4
# :class: dropdown
# #### Part 1: Porosity ($\phi$)
# A Simple Cubic (SC) packing arrangement contains one sphere per unit cell. The radius of each sphere is $R$.
#
# The length of one side of the cubic unit cell is exactly equal to the diameter of two touching spheres:
# $$a = 2R$$
#
# The total volume of the unit cell ($V_{total}$) is:
# $$V_{total} = a^3 = (2R)^3 = 8R^3$$
#
# The solid volume inside the unit cell ($V_{solid}$) consists of 8 corner pieces, where each corner represents 1/8 of a sphere. Thus, the total solid volume is equal to the volume of one single sphere:
# $$V_{solid} = \frac{4}{3}\pi R^3$$
#
# The porosity ($\phi$) is the ratio of the void volume to the total volume:
# $$\phi = \frac{V_{void}}{V_{total}} = \frac{V_{total} - V_{solid}}{V_{total}} = 1 - \frac{V_{solid}}{V_{total}}$$
#
# Substituting the volume expressions:
# $$\phi = 1 - \frac{\frac{4}{3}\pi R^3}{8R^3} = 1 - \frac{\pi}{6}$$
#
# Evaluating numerically:
# $$\phi \approx 1 - 0.5236 = 0.476$$
#
# #### Part 2: Specific Surface Area ($a_v$)
# The specific surface area per unit volume of the **total bed** ($a_v$) is defined as the total interstitial surface area divided by the total volume of the unit cell.
#
# The surface area of the single sphere inside the unit cell is:
# $$A_{sphere} = 4\pi R^2$$
#
# Dividing this by the total unit cell volume ($V_{total} = 8R^3$):
# $$a_v = \frac{A_{sphere}}{V_{total}} = \frac{4\pi R^2}{8R^3} = \frac{\pi}{2R}$$
#
# *Alternative method using solid phase specific surface area ($a_s$):*
# $$a_s = \frac{\text{Surface Area}}{\text{Solid Volume}} = \frac{4\pi R^2}{\frac{4}{3}\pi R^3} = \frac{3}{R}$$
# $$a_v = a_s (1 - \phi) = \frac{3}{R} \left(\frac{\pi}{6}\right) = \frac{\pi}{2R}$$
#
# #### Part 3: Tortuosity Factor ($\tau$)
# Geometric tortuosity is defined as the ratio of the actual microscopic fluid path length ($L_e$) to the macroscopic straight line length of the porous medium ($L$):
# $$\tau = \frac{L_e}{L}$$
#
# In a Simple Cubic lattice model, the open channels run perfectly straight and parallel along the principal coordinate axes. A fluid molecule traveling parallel to a principal axis experiences no geometric deflections or forced deviations around spheres.
#
# Therefore, the effective path length is identical to the bed length:
# $$\text{Because } L_e = L \implies \tau = 1.0$$
#
#
# :::
#
# :::{admonition} Body-centered and face-centered cubic packing
# In case you are wondering, $\phi$ drops for the other mentioned packing types to $0.320$, and $0.260$ respectively. You can verify this using a similar method as shown in the solution.
# :::

# %% [markdown]
# #### Test quiz - parameterized

# %%
import json
import random
from jupyterquiz import display_quiz

# 1. Generate dynamic input variables within your chosen ranges
rho_matrix = round(random.uniform(2.50, 2.80), 2)  # g/cm3 (Typical mineral density)
V_tot = round(random.uniform(500.0, 1000.0), 1)    # cm3
phi_target = random.uniform(0.30, 0.50)            # Target a realistic porosity (30%-50%)

# Calculate a matching dry mass based on target porosity
V_matrix = V_tot * (1 - phi_target)
m_dry = round(V_matrix * rho_matrix, 1)

# Generate a realistic water mass that doesn't over-saturate the pores
max_water_mass = V_tot * phi_target * 1.0          # Water density = 1.0 g/cm3
m_water = round(random.uniform(0.2 * max_water_mass, 0.8 * max_water_mass), 1)
m_tot = round(m_dry + m_water, 1)

# 2. Perform the exact math engine calculations
rho_w = 1.0
actual_V_matrix = m_dry / rho_matrix
actual_V_void = V_tot - actual_V_matrix

ans_phi = round(actual_V_void / V_tot, 2)
ans_e = round(actual_V_void / actual_V_matrix, 2)
ans_theta = round((m_tot - m_dry) / (rho_w * V_tot), 2)

# Saturated mass for 1 m3 (1,000,000 cm3) in kg
V_1m3 = 1000000.0
sat_mass_g = ((1.0 - ans_phi) * V_1m3 * rho_matrix) + (ans_phi * V_1m3 * rho_w)
ans_sat_mass = round(sat_mass_g / 1000.0, 1)

# 3. Load JSON and inject text variables + numeric answers
with open("../quiz/2_SPF_PM/q_TEST_.json", "r") as file:
    quiz_data = json.load(file)

# Format the text parameters inside the question fields
for item in quiz_data:
    item["question"] = item["question"].format(
        m_tot=m_tot, m_dry=m_dry, V_tot=V_tot, rho_matrix=rho_matrix
    )

# Assign calculated math answers directly to their placeholders
quiz_data[0]["answers"][0]["value"] = ans_phi
quiz_data[1]["answers"][0]["value"] = ans_e
quiz_data[2]["answers"][0]["value"] = ans_theta
quiz_data[3]["answers"][0]["value"] = ans_sat_mass

# 4. Run the quiz
display_quiz(quiz_data)
# Out:
# <div id="zqHVDiSHYvLI" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #zqHVDiSHYvLI {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# ### Question 5 - Grain size distribution, intrinsic permeability and permeability models
# Porous materials can be characterized based on the solid materials, the voids, or both. One way to do so, is to look at the sizes of the various solid particles (if the porous material is made of particles) or pores. For example, for natural porous materials such as sand, you could sieve them using sieves of various raster sizes, see @fig-sieves. Doing so can give you data as in @tab-psd and @fig-psd1.
#
# :::{figure} ../figures/2_SPF_PM/Laboratory_sieves_BMK.jpg
# :label: fig-sieves
# :alt: sieves used in geology, physical geography, hydrology etc. for field classification of soils and rocks.
# :width: 400px
# :align: center
#
# Sieves used in geology, physical geography, hydrology etc. for field classification of soils and rocks.
# [By BMK Wikimedia, CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=650352](https://commons.wikimedia.org/wiki/Category:Sieves#/media/File:Laboratory_sieves_BMK.jpg)
# :::
#
# :::{table} Particle size distribution data
# :label: tab-psd
#
# | Size (mm) | Percent finer by weight (%) |
# |-----------|------------------------------|
# | 10.0      | 99                           |
# | 5.0       | 98                           |
# | 2.0       | 95                           |
# | 1.0       | 93                           |
# | 0.5       | 88                           |
# | 0.2       | 35                           |
# | 0.1       | 10                           |
# | 0.05      | 6                            |
# :::
#
# :::{figure} ../figures/2_SPF_PM/psd1.png
# :label: fig-psd1
# :alt: grain size distribution (cumulative and regular) based on @tab-psd.
# :width: 600px
# :align: center
#
# Grain size distribution (cumulative and regular) based on @tab-psd.
# :::

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# 1. Raw Data Input
sizes = np.array([10.0, 5.0, 2.0, 1.0, 0.5, 0.2, 0.1, 0.05])
percent_finer = np.array([99, 98, 95, 93, 88, 35, 10, 6])

# 2. Conversion to Regular/Frequency Distribution
frequencies = -np.diff(percent_finer)  # Mass retained per interval
bin_midpoints = np.sqrt(sizes[:-1] * sizes[1:])  # Geometric midpoints for log-scale

# 3. Scientific Smoothing (Interpolation in Log-Space)
# Sort in ascending order for the spline engine to function correctly
log_midpoints_sorted = np.sort(np.log10(bin_midpoints))
frequencies_sorted = frequencies[np.argsort(np.log10(bin_midpoints))]

# Generate a high-resolution smooth range in log-space
log_x_smooth = np.linspace(log_midpoints_sorted.min(), log_midpoints_sorted.max(), 300)
x_smooth = 10**log_x_smooth  # Convert back to physical sizes (mm)

# Apply Cubic Spline interpolation
spline = make_interp_spline(log_midpoints_sorted, frequencies_sorted, k=3)
y_smooth = spline(log_x_smooth)

# Clamp values to 0 to preserve physics (frequencies cannot be negative)
y_smooth = np.clip(y_smooth, 0, None)

# 4. Plotting Setup
fig, ax1 = plt.subplots(figsize=(11, 6))

# --- Plot 1: Cumulative Curve (Left Axis) ---
color_cum = 'darkblue'
ax1.plot(sizes, percent_finer, marker='o', color=color_cum, linewidth=2.5, label='Cumulative (Percent Finer)')
ax1.set_xlabel('Particle Size (mm) [Log Scale]', fontsize=12)
ax1.set_ylabel('Percent Finer by Weight (%)', color=color_cum, fontsize=12)
ax1.tick_params(axis='y', labelcolor=color_cum)
ax1.set_ylim(0, 105)
ax1.set_xscale('log')
ax1.set_xlim(12.0, 0.04)  # Geotechnical convention: large to small
ax1.grid(True, which="both", linestyle=":", alpha=0.5)

# --- Plot 2: Regular Frequency Distribution (Right Axis) ---
ax2 = ax1.twinx()
color_freq = 'crimson'

# Historical Interval Bars
widths = np.abs(np.diff(np.log10(sizes))) 
ax2.bar(bin_midpoints, frequencies, width=widths*bin_midpoints*0.6, 
        color=color_freq, alpha=0.2, edgecolor=color_freq, 
        linewidth=1, linestyle='--', label='Interval Mass Fraction (Bars)')

# Scientific Smoothed Frequency Curve Overlay
ax2.plot(x_smooth, y_smooth, color=color_freq, linewidth=2.5, 
         label='Continuous Grain Size Frequency (Smoothed)')

ax2.set_ylabel('Interval Mass Fraction (%) / Probability Density', color=color_freq, fontsize=12)
ax2.tick_params(axis='y', labelcolor=color_freq)
ax2.set_ylim(0, 60)

# Title and Legend Layout
plt.title('Grain Size Analysis: Cumulative and Log-Space Smoothed Frequency Curve', fontsize=14, pad=15)
fig.tight_layout()

# Consolidate legends from both active axes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left', fontsize=11)

plt.show()

# %%
display_quiz("../quiz/2_SPF_PM/q_Permmodel.json")
# Out:
# <div id="waVFoyTFftcp" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #waVFoyTFftcp {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# :::{hint} Hints Question 5
# :class: dropdown
# * a) There are several forms of the Kozeny-Carman equation. As you have been given particle sizes, can you find a form that uses $d_{particle}$? Here we are looking for $d_{10}$, which is the grain size of which only 10% of the grains are finer than that particular size.
# * b) This should be simple: just adapt the porosity and repeat a). Please ask yourself: can I explain what happens when I reduce the porosity? What happens to the pores? What does that mean for the permeability?
# * c) To really know $C$ you would need experimental data and make a fit. All Hazen's model is, is a proposal for a quadratic relationship between this particular grain size and hydraulic conductivity. So do not forget to convert hydraulic conductivity to intrinsic permeability! Here, you can use $C=100$. Incidentally: what are the dimensions (and units) of $C$?
#
# :::
# ::::{tip} Solution Question 5
# :class: dropdown
#
# #### a) Kozeny-Carman for a porous material with known matrix particle sizes
#
# The Kozeny-Carman equation is
#
# \begin{equation*}
# k=\frac{d^{2}}{180}\frac{\phi^{3}}{(1-\phi)^{2}}
# \end{equation*}
#
# where:
#
# - $k = \text{ intrinsic permeability } (\mathrm{m^2})$
# - $d = \text{ representative grain diameter } (\mathrm{m})$
# - $\phi = \text{ porosity}$
#
# ##### Step 1: Determine the effective grain size
#
# The particle size distribution in @tab-psd gives:
#
# | Size (mm) | Percent finer (%) |
# |-----------|-------------------|
# | 0.20 | 35 |
# | 0.10 | 10 |
#
# The effective diameter $d_{10}$ corresponds to 10% finer:
#
# \begin{equation*}
# d_{10}=0.10~\mathrm{ mm}
# \end{equation*}
#
# Convert to metres:
#
# \begin{equation*}
# d_{10}=0.10\times 10^{-3}
# =1.0\times10^{-4}\ \mathrm{m}
# \end{equation*}
#
# ##### Step 2: Calculate permeability for $\phi=0.37$
#
# \begin{equation*}
# k= \frac{(1.0\times10^{-4})^2}{180} \frac{(0.37)^3}{(1-0.37)^2}
# \end{equation*}
#
# \begin{equation*}
# k= \frac{1.0\times10^{-8}}{180} \frac{0.050653}{0.3969}
# \end{equation*}
#
# \begin{equation*}
# k=7.09\times10^{-12}\ \mathrm{m^2}
# \end{equation*}
#
# ##### Answer
#
# \begin{equation*}
# \boxed{k=7.09\times10^{-12}\ \mathrm{m^2}}
# \end{equation*}
#
# #### b) Kozeny-Carman for a porous material with known matrix particle sizes with a porosity decrease
#
# ##### The new porosity is
#
# \begin{equation*}
# \phi_{\text{new}}
# =0.37(1-0.25) = 0.2775
# \end{equation*}
#
# ##### Using the same grain diameter:
#
# \begin{equation*}
# k_{\text{new}} = \frac{(1.0\times10^{-4})^2}{180} \frac{(0.2775)^3}{(1-0.2775)^2}
# \end{equation*}
#
# \begin{equation*}
# k_{\text{new}} = 5.56\times10^{-11}\left(\frac{0.021373}{0.522006}\right)
# \end{equation*}
#
# \begin{equation*}
# k_{\text{new}}= 2.28 \times 10^{-12}\ \mathrm{m^2}
# \end{equation*}
#
# ##### Answer
# \begin{equation*}
# \boxed{k_{\text{new}}=2.28\times10^{-12}\ \mathrm{m^2}}
# \end{equation*}
#
# :::{warning}
#
# ##### Change in permeability
# \begin{equation*}
# \frac{k_{\text{new}}}{k}= \frac{2.28\times10^{-12}} {7.09\times10^{-12}} = 0.321
# \end{equation*}
#
# The intrinsic permeability is now only approximately one-third of its original value!
# Note how the 25% reduction in porosity is leading to 67% permeability reduction.
# :::
#
# #### c) Hazen equation for clean sands (a particular porous material!)
# The Hazen equation is an empirical relationship for estimating the hydraulic conductivity of clean sands:
#
# \begin{equation*}
# K = C \cdot d_{10}^{2}
# \end{equation*}
#
# where:
#
# $K$ = hydraulic conductivity
# $d_{10}$ = effective grain size
# $C$ = empirical coefficient
# For clean, uniformly graded sands, a commonly used value is
#
# \begin{equation*}
# C = 100
# \end{equation*}
#
# with $d_{10}$ expressed in cm and $K$ obtained in cm/s.
#
# ##### Step 1: Determine $d_{10}$
# From @tab-psd:
# | Size (mm) | Percent finer (%) |
# |-----------|-------------------|
# | 0.10      | 10                |
#
# Therefore,
#
# \begin{equation*}
# d_{10}=0.10\ \text{mm}
# \end{equation*}
#
# Convert to cm:
#
# \begin{equation*}
# d_{10}=0.01\ \text{cm}
# \end{equation*}
#
# ##### Step 2: Calculate hydraulic conductivity
# \begin{equation*}
# K = 100(0.01)^2
# \end{equation*}
#
# \begin{equation*}
# K = 0.01\ \text{cm/s}
# \end{equation*}
#
# Convert to SI units:
#
# \begin{equation*}
# K = 1.0\times10^{-4}\ \text{m/s}
# \end{equation*}
#
# ##### Step 3: Convert hydraulic conductivity to intrinsic permeability
# The relationship between hydraulic conductivity and intrinsic permeability is
#
# \begin{equation*}
# k=\frac{K\mu}{\rho g}
# \end{equation*}
#
# Using properties of water at $20^\circ\text{C}$:
#
# \begin{equation*}
# \mu = 1.002\times10^{-3}\ \text{Pa}\cdot\text{s}
# \end{equation*}
#
# \begin{equation*}
# \rho = 1000\ \text{kg/m}^3
# \end{equation*}
#
# \begin{equation*}
# g = 9.81\ \text{m/s}^2
# \end{equation*}
#
# Substituting:
#
# \begin{equation*}
# k\frac{(1.0\times10^{-4})(1.002\times10^{-3})} {(1000)(9.81)}
# \end{equation*}
#
# \begin{equation*}
# k = 1.02\times10^{-11}\ \text{m}^2
# \end{equation*}
#
# Answer
# \begin{equation*}
# \boxed{k = 1.02\times10^{-11}\ \mathrm{m^2}}
# \end{equation*}
#
# This estimate is somewhat larger than the Kozeny-Carman result because Hazen's equation is an empirical correlation developed for clean sands and tends to give relatively high permeability estimates.
#
# ::::

# %% [markdown]
# ### Question 6 - Pore size distributions
# So far we have considered simple configurations of the matrix. Consequently the distribution of the pores has also been simple. For instance, we considered a unit cell in the Simple Cubic Packing and computed some properties of that porous material. The underlying assumption was that the unit cell described a homogeneous isotropic porous material completely. So if we were to map the distribution of the grains - or more relevant for our studies - the distribution of the pores we would get a very narrow distribution. For actual porous materials that distribution can be quite different. Of course, the distribution of pore sizes provides already much more information than just the bulk porosity or an average pore size. This means we can also attempt to resolve flow at greater details.
#
# Consider @fig-psd2 below.
#
# :::{figure} ../figures/2_SPF_PM/psd2.png
# :label: fig-psd2
# :alt: Relative pore size distributions for porous materials used in fuel cells and geotechnical applications - based on dummy data.
# :width: 800px
# :align: center
#  Relative pore size distributions for porous materials used in fuel cells and geotechnical applications - based on dummy data.
# :::

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# Instellingen voor de figuur
plt.figure(figsize=(11, 6))

# Assen genereren op een logaritmische schaal (omdat brandstofcellen nm-schaal hebben en zandsteen micrometer-schaal)
# Om ze visueel goed te vergelijken op een genormaliseerde as (of effectieve schaal):
x = np.logspace(-3, 2, 2000)

# --- 1. Ideale Simple Cubic Pakking (Theorie) ---
# We centreren de SC pieken puur hypothetisch rond de 1 voor de visuele vergelijking
r_throat = 0.414
r_body = 0.732
y_sc = 0.4 * norm.pdf(x, r_throat, 0.01) + 0.6 * norm.pdf(x, r_body, 0.01)
y_sc = y_sc / max(y_sc) * 90

# --- 2. Natuurlijke Zandsteen (Monomodaal, breed) ---
# Gecentreerd rond grotere poriën met een brede, natuurlijke spreiding
y_sandstone = norm.pdf(np.log10(x), np.log10(2.0), 0.4)
y_sandstone = y_sandstone / max(y_sandstone) * 70

# --- 3. Brandstofcel Katalysatorlaag (Bispedaal / Bimodal) ---
# Twee duidelijke pieken: één op de micro/mesoschaal en één op de macroschaal
y_fuelcell = 0.6 * norm.pdf(np.log10(x), np.log10(0.03), 0.3) + 0.4 * norm.pdf(np.log10(x), np.log10(0.8), 0.3)
y_fuelcell = y_fuelcell / max(y_fuelcell) * 60

# Plots tekenen
plt.plot(x, y_sc, color='darkblue', linewidth=2.5, label='Simple Cubic Model (Discrete)')
plt.fill_between(x, 0, y_sc, color='darkblue', alpha=0.05)

plt.plot(x, y_sandstone, color='crimson', linewidth=2.5, linestyle='--', label='Sandstone rocks (Continuous, Monomodal)')
plt.fill_between(x, 0, y_sandstone, color='crimson', alpha=0.05)

plt.plot(x, y_fuelcell, color='forestgreen', linewidth=2.5, linestyle='-.', label='Fuel cell catalyst (Bimodal)')
plt.fill_between(x, 0, y_fuelcell, color='forestgreen', alpha=0.05)

# Grafiekopmaak met logaritmische X-as om de uitersten goed te tonen
plt.xscale('log')
plt.title('Pore size distribution (PSD): Comparison between 3 different porous materials based on dummy data', fontsize=14, pad=15)
plt.xlabel('Indicative pore radius (Normalized scale)', fontsize=12)
plt.ylabel('Relative volume fraction (%)', fontsize=12)
plt.xlim(0.005, 20.0)
plt.ylim(0, 100)
plt.grid(True, which="both", linestyle=':', alpha=0.5)

# Belangrijke annotaties
plt.annotate('Secundary Macropores \n(Gas transport)', xy=(0.8, 25), xytext=(2.0, 40),
             arrowprops=dict(arrowstyle="->", color='forestgreen'))
plt.annotate('Primary Mesopores \n(Catalysis reaction)', xy=(0.03, 35), xytext=(0.006, 55),
             arrowprops=dict(arrowstyle="->", color='forestgreen'))

plt.legend(fontsize=11, loc='upper right')
plt.show()

# %%
import json
from jupyterquiz import display_quiz

display_quiz("../quiz/2_SPF_PM/q_pore_size_dist_grain_size_dist.json")
# Out:
# <div id="xQrfpsrMjFlw" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #xQrfpsrMjFlw {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# ::::{hint} Hint Question 6
# :class: dropdown
#
# ::::
# :::{tip} Solution Question 6
# :class: dropdown
# #### Part 1: Scaling Grain Distributions to Pore Distributions
# Porosity and geometric distribution tracking are dimensionless scaling operations. The geometry of a pore throat is bounded strictly by the surrounding grain surfaces. For any rigid, stable packing configuration, the characteristic pore radius ($r$) scales linearly with the characteristic grain radius ($R$):
# $$r \propto R$$
#
# If a catalyst layer and a sandstone share the exact same structural packing geometry but the catalyst's grains are 1000 times smaller (3 orders of magnitude), the individual pore channels will also be exactly 1000 times smaller.
#
# Because the relative variations (sorting/polydispersity) are identical, the shape of the cumulative Pore Size Distribution (PSD) remains completely unchanged. It merely shifts down uniformly along the logarithmic x-axis (pore radius) by 3 orders of magnitude. Porosity itself is a scale-independent ratio and remains identical for both samples.
#
# ---
#
# #### Part 2: Bimodal Pore Size Distribution in Fuel Cells
# A Polymer Electrolyte Membrane Fuel Cell (PEMFC) catalyst layer requires an engineered, multi-scale pore environment because it facilitates simultaneous, competing transport phenomena:
#
# * **Micro/Mesopores (< 50 nm):** These ultra-small pores maximize the internal specific surface area ($a_v \\propto 1/R$). This provides an enormous density of active catalytic sites (e.g., Platinum) necessary to achieve high electrochemical reaction rates.
# * **Macropores (> 100 nm):** Viscous flow and gas diffusion become severely limited in narrow sub-50 nm channels due to wall collisions (Knudsen diffusion) and liquid water clogging (capillary condensation). Macropores act as transport "highways," allowing oxygen/hydrogen reactant gases to quickly enter and liquid water product to be drained away dynamically without flooding the reaction sites.
#
#
# :::

# %% [markdown]
# ### Question 7 - A matter of configuration. Or: configuration matters?

# %%
import json
from jupyterquiz import display_quiz

display_quiz("../quiz/2_SPF_PM/q_psd_design.json")
# Out:
# <div id="dczwGMgTHFjO" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #dczwGMgTHFjO {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# :::{hint} Hint Question 7
# :class: dropdown
# hint
# :::
# :::{tip} Solution Question 7
# :class: dropdown
# #### Part 1: Serial vs. Parallel Configurations
# Even if Filter A and Filter B contain the exact same volume fractions of large and small pores, their macroscopic fluid conductivities will differ dramatically due to network topology:
#
# * **Filter B (Parallel Setup):** Fluid flows through the large and small pores simultaneously. Because volumetric flow rate through a pore is highly sensitive to radius ($\text{Flow Rate} \propto R^4$ via Hagen-Poiseuille), the continuous large-pore channels act as low-resistance paths. The overall conductivity is dominated by these open paths, yielding a very high macroscale permeability.
# * **Filter A (Serial Setup):** Fluid is forced to pass sequentially through a large pore, then a small pore, then a large pore. In a series network, the total fluid transport is throttled by the highest resistance element in the chain—the narrow pore throats. The small pores act as global volumetric bottlenecks, drastically reducing the overall hydraulic conductivity.
#
# ---
#
# #### Part 2: Optimization via Pore Network Modeling (PNM)
# Pore Network Modeling demonstrates that an engineer can optimize or tune the permeability of a porous material without changing its overall weight or volumetric porosity ($\phi$). This is achieved by manipulating the **spatial topology**:
#
# * **Coordination Number:** Increasing the number of active inter-pore connections (throats) branching out from each pore body. This creates redundant flow paths, ensuring that if one path is blocked or tight, the fluid can bypass it easily.
# * **Eliminating Serialization:** Designing the manufacturing process (e.g., 3D printing, sintered gradients, or targeted acid etching) to group larger pores into continuous, uninterrupted flow streams parallel to the pressure gradient while isolating or limiting bottleneck configurations. This minimizes the effective tortuosity factor ($\tau$) and increases macroscale hydraulic conductivity at a fixed density.
#
#
# :::

# %% [markdown]
# ### Question 8 - Hydraulic head 1
# As you hopefully remember, the hydraulic head can be viewed as an expression of the Bernoulli equation, which in its turn is a form of conservation of energy. If you would check the dimensions of the Bernoulli equation, you will see that if you divide all terms in the equation by $\rho g$ the terms obtain the dimension of $[L]$. The benefit is that the somewhat abstract concept of energy is now expressed in a tanglible height. For instance, the height of the top of a water column above a chosen reference level. This is called the hydraulic head and its definition for slow flow, such as groundwater flow, is:
# ```{math}
# :label: hh-eq-1
#
# h \equiv \frac{p}{\rho g}+z
#
# ```

# %%
display_quiz("../quiz/2_SPF_PM/q_Hydraulic_head_1.json")
# Out:
# <div id="VPqkTPUaMmba" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #VPqkTPUaMmba {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# :::{tip} Solution Question 8
# :class: dropdown
#
# #### Step 1: Calculate the exit velocity
#
# The volumetric flow rate is
#
# \begin{equation*}
# Q = 2~\mathrm{L/s}
# = 2\times10^{-3}~\mathrm{m^3/s}
# \end{equation*}
#
# The hose diameter is
#
# \begin{equation*}
# d = 2~\mathrm{cm}
# = 0.02~\mathrm{m}
# \end{equation*}
#
# The cross-sectional area is
#
# \begin{equation*}
# A = \frac{\pi d^2}{4}
# = \frac{\pi(0.02)^2}{4}
# = 3.14\times10^{-4}~\mathrm{m^2}
# \end{equation*}
#
# The exit velocity is
#
# \begin{equation*}
# v = \frac{Q}{A}
# = \frac{2\times10^{-3}}{3.14\times10^{-4}}
# = 6.37~\mathrm{m/s}
# \end{equation*}
#
# #### Step 2: Determine the hydraulic head at the hose outlet
#
# Bernoulli head is
#
# \begin{equation*}
# h = z + \frac{p}{\rho g} + \frac{v^2}{2g}
# \end{equation*}
#
# At the hose outlet, the water is exposed to the atmosphere, so
#
# \begin{equation*}
# \frac{p}{\rho g}=0
# \end{equation*}
#
# The elevation is
#
# \begin{equation*}
# z = 134.5~\mathrm{m}
# \end{equation*}
#
# The velocity head is:
#
# \begin{equation*}
# \frac{v^2}{2g} =\frac{(6.37)^2}{2(9.81)}=2.07~\mathrm{m}
# \end{equation*}
#
# Therefore,
#
# \begin{equation*}
# h = 134.5 + 2.07 = 136.57~\mathrm{m}
# \end{equation*}
#
# ##### Answer: Hydraulic Head
#
# \begin{equation*}
# \boxed{h = 136.57~\mathrm{m}}
# \end{equation*}
#
# #### Step 3: Determine the maximum elevation reached by the water
#
# Assuming the hydraulic head remains constant along the trajectory and that the velocity at the highest point is zero,
#
# \begin{equation*}
# v = 0
# \end{equation*}
#
# and the pressure is atmospheric:
#
# \begin{equation*}
# \frac{p}{\rho g}=0
# \end{equation*}
#
# Thus,
#
# \begin{equation*}
# h = z_{\max}
# \end{equation*}
#
# Substituting the previously calculated head:
#
# \begin{equation*}
# z_{\max}=136.57~\mathrm{m}
# \end{equation*}
#
# ##### Answer: Maximum Elevation
#
# The highest elevation reached by the water jet is
#
# \begin{equation*}
# \boxed{z_{\max}=136.57~\mathrm{m}}
# \end{equation*}
#
# This corresponds to a rise above the hose outlet of
#
# \begin{equation*}
# 136.57 - 134.5=2.07~\mathrm{m}
# \end{equation*}
#
# or
#
# \begin{equation*}
# \boxed{2.07~\mathrm{m}}
# \end{equation*}
#
# above the end of the hose.
#
# :::

# %% [markdown]
# ### Question 9 - Permeability and (hydraulic) conductivity 1

# %%
display_quiz("../quiz/2_SPF_PM/q_Darcy_1.json")
# Out:
# <div id="zHpXLWzWtTFX" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #zHpXLWzWtTFX {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# :::{hint} Hints Question 9
# :class: dropdown
#
# * a) Please check the definition for specific discharge and the average linear velocity. Make sure you know them by heart and can explain them.
# * b) -
# * c) This is asking about Darcy's law.
# * d) -
#
# :::
# :::{tip} Solution Question 9
# :class: dropdown
#
# #### a) Calculate the specific discharge $q_x$
#
# The average linear velocity and specific discharge are related through
#
# \begin{equation*}
# \overline{v}_x=\frac{q_x}{\phi}
# \end{equation*}
#
# Rearranging:
#
# \begin{equation*}
# q_x=\phi\,\overline{v}_x
# \end{equation*}
#
# Substituting the given values:
#
# \begin{equation*}
# q_x=(0.34)(13)
# =4.42~\mathrm{m/day}
# \end{equation*}
#
# ##### Answer
#
# \begin{equation*}
# \boxed{q_x=4.42~\mathrm{m/day}}
# \end{equation*}
#
# #### b) Estimate the total discharge $Q$
#
# The flow area is the thickness of the sand layer multiplied by the length of the dam:
#
# \begin{equation*}
# A=(0.6)(95)
# =57.0~\mathrm{m^2}
# \end{equation*}
#
# The total discharge is
#
# \begin{equation*}
# Q=q_xA
# \end{equation*}
#
# Substituting:
#
# \begin{equation*}
# Q=(4.42)(57.0)
# =251.94~\mathrm{m^3/day}
# \end{equation*}
#
# ##### Answer
#
# \begin{equation*}
# \boxed{Q=251.94~\mathrm{m^3/day}}
# \end{equation*}
#
# #### c) Estimate the hydraulic conductivity $K_x$
#
# According to Darcy's law,
#
# \begin{equation*}
# q_x=K_x\,i
# \end{equation*}
#
# where the hydraulic gradient is
#
# \begin{equation*}
# i=\frac{\Delta h}{L}
# \end{equation*}
#
# Substituting the given values:
#
# \begin{equation*}
# i=\frac{14}{25}
# =0.56
# \end{equation*}
#
# Therefore,
#
# \begin{equation*}
# K_x=\frac{q_x}{i}
# \end{equation*}
#
# \begin{equation*}
# K_x=\frac{4.42}{0.56}
# =7.89~\mathrm{m/day}
# \end{equation*}
#
# ##### Answer
#
# \begin{equation*}
# \boxed{K_x=7.89~\mathrm{m/day}}
# \end{equation*}
#
# :::

# %% [markdown]
# ## Experimental methods
# In this lecture we only covered (some variations of) the apparatus that Darcy himself used back in the 19th century. Nowadays we call such an apparatus a 'permeameter'. A simplified image of such a permeameter is shown in @fig-permeameter.
#
# :::{figure} ../figures/2_SPF_PM/Permeameter.png
# :alt: Simplified representation of a permeameter.
# :width: 400px
# :align: center
# :label: fig-permeameter
#
# Simplified representation of a permeameter. Notice the porous disks that provide solid physical support for the sample specimen while allowing free water or gas passage. Some permeameters allow for applying stresses to the sample ('loading'). In that case the porous disk is supposed to evenly distribute both the load and the fluid.
# :::
#
# ### Question 10 - Constant head test

# %%
display_quiz("../quiz/2_SPF_PM/q_Darcy_2.json")
# Out:
# <div id="YEJMrprxmTVe" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #YEJMrprxmTVe {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# :::{hint} Hints Question 10
# :class: dropdown
# * a, c, d, e) Study the constant head set-up and experiment from Darcy. All answers can be found using simple algebra and keeping track of the different types of velocity we use in studying porous materials. Mind also the difference between conductivity and permeability!
# * b) -
# :::
# :::{tip} Solution Question 10
# :class: dropdown
# #### a) Hydraulic conductivity
# ##### Step 1: Determine the hydraulic gradient
#
# The head difference across the sample is
#
# \begin{equation*}
# \Delta h = h_1-h_2
# \end{equation*}
#
# Substituting the given values:
#
# \begin{equation*}
# \Delta h = 95.0-37.0
# =58.0~\mathrm{cm}
# \end{equation*}
#
# The hydraulic gradient is
#
# \begin{equation*}
# i=\frac{\Delta h}{L}
# \end{equation*}
#
# \begin{equation*}
# i=\frac{58.0}{20.0}
# =2.90
# \end{equation*}
#
# ##### Step 2: Calculate the cross-sectional area
#
# The sample radius is
#
# \begin{equation*}
# r=1.5~\mathrm{cm}
# \end{equation*}
#
# The cross-sectional area is
#
# \begin{equation*}
# A=\pi r^2
# \end{equation*}
#
# \begin{equation*}
# A=\pi(1.5)^2
# =7.069~\mathrm{cm^2}
# \end{equation*}
#
# ##### Step 3: Calculate the specific discharge
#
# The volumetric flow rate is
#
# \begin{equation*}
# Q=3.5~\mathrm{cm^3/min}
# \end{equation*}
#
# Convert to \(\mathrm{cm^3/s}\):
#
# \begin{equation*}
# Q=\frac{3.5}{60}
# =0.05833~\mathrm{cm^3/s}
# \end{equation*}
#
# The specific discharge is
#
# \begin{equation*}
# q=\frac{Q}{A}
# \end{equation*}
#
# \begin{equation*}
# q = \frac{0.05833}{7.069} = 0.00825~\mathrm{cm/s}
# \end{equation*}
#
# ##### Step 4: Calculate the hydraulic conductivity
#
# Darcy's law gives
#
# \begin{equation*}
# q=Ki
# \end{equation*}
#
# Therefore,
#
# \begin{equation*}
# K=\frac{q}{i}
# \end{equation*}
#
# \begin{equation*}
# K=\frac{0.00825}{2.90}=2.85\times10^{-3}~\mathrm{cm/s}
# \end{equation*}
#
# ##### Answer
#
# \begin{equation*}
# \boxed{K=2.85\times10^{-3}~\mathrm{cm/s}}
# \end{equation*}
# #### b) Multiple choice question
# Answer is already displayed at the question.
#
# #### c) Calculate the average linear velocity
#
# Darcy's law gives the specific discharge:
#
# \begin{equation*}
# q_x = K i
# \end{equation*}
#
# Substituting the given values:
#
# \begin{equation*}
# q_x = (0.7)(0.012)
# = 0.0084~\mathrm{m/day}
# \end{equation*}
#
# The average linear velocity is related to the specific discharge by
#
# \begin{equation*}
# \overline{v}_x=\frac{q_x}{\phi}
# \end{equation*}
#
# Therefore,
#
# \begin{equation*}
# \overline{v}_x =
# \frac{0.0084}{0.32} =
# 0.02625~\mathrm{m/day}
# \end{equation*}
#
# ##### Answer
#
# \begin{equation*}
# \boxed{\overline{v}_x = 0.03~\mathrm{m/day}}
# \end{equation*}
#
# #### d) Calculate the intrinsic permeability
#
# The relationship between hydraulic conductivity and intrinsic permeability is
#
# \begin{equation*}
# K=\frac{k\rho g}{\mu}
# \end{equation*}
#
# Rearranging:
#
# \begin{equation*}
# k=\frac{K\mu}{\rho g}
# \end{equation*}
#
# First convert the hydraulic conductivity to SI units:
#
# \begin{equation*}
# K=0.7~\mathrm{m/day}=
# \frac{0.7}{86400}=
# 8.10\times10^{-6}~\mathrm{m/s}
# \end{equation*}
#
# For water at \(20^\circ\mathrm{C}\),
#
# \begin{equation*}
# \mu = 1.002\times10^{-3}~\mathrm{Pa\,s}
# \end{equation*}
#
# \begin{equation*}
# \rho = 1000~\mathrm{kg/m^3}
# \end{equation*}
#
# \begin{equation*}
# g = 9.81~\mathrm{m/s^2}
# \end{equation*}
#
# Substituting:
#
# \begin{equation*}
# k=\frac{(8.10\times10^{-6})(1.002\times10^{-3})}
# {(1000)(9.81)}
# \end{equation*}
#
# \begin{equation*}
# k = 8.27\times10^{-13}~\mathrm{m^2}
# \end{equation*}
#
# ##### Answer
#
# \begin{equation*}
# \boxed{k = 8.27\times10^{-13}~\mathrm{m^2}}
# \end{equation*}
#
# #### e) Determine the conductivity for different fluids
#
# For a given porous medium, the intrinsic permeability remains constant. Hydraulic conductivity depends on the fluid according to
#
# \begin{equation*}
# K=\frac{k\rho g}{\mu}
# \end{equation*}
#
# ##### Water
#
# Using the original properties:
#
# \begin{equation*}
# K_{\mathrm{water}}=8.10\times10^{-6}~\mathrm{m/s}
# \end{equation*}
#
# \begin{equation*}
# K_{\mathrm{water}}=
# 0.70~\mathrm{m/day}
# \end{equation*}
#
# ##### Leaded gasoline
#
# Assume
#
# \begin{equation*}
# \rho = 740~\mathrm{kg/m^3}
# \end{equation*}
#
# \begin{equation*}
# \mu = 6.0\times10^{-4}~\mathrm{Pa\,s}
# \end{equation*}
#
# Then
#
# \begin{equation*}
# K_{\mathrm{gasoline}}=\frac{(8.27\times10^{-13})(740)(9.81)}
# {6.0\times10^{-4}}
# \end{equation*}
#
# \begin{equation*}
# K_{\mathrm{gasoline}}=
# 1.00\times10^{-5}~\mathrm{m/s}
# \end{equation*}
#
# Converting to m/day:
#
# \begin{equation*}
# K_{\mathrm{gasoline}}
# = 0.87~\mathrm{m/day}
# \end{equation*}
#
# ##### Arabian medium crude oil
#
# Assume
#
# \begin{equation*}
# \rho = 870~\mathrm{kg/m^3}
# \end{equation*}
#
# \begin{equation*}
# \mu = 6.0\times10^{-3}~\mathrm{Pa\,s}
# \end{equation*}
#
# Then
#
# \begin{equation*}
# K_{\mathrm{crude}}
# =\frac{(8.27\times10^{-13})(870)(9.81)}
# {6.0\times10^{-3}}
# \end{equation*}
#
# \begin{equation*}
# K_{\mathrm{crude}}
# =1.18\times10^{-6}~\mathrm{m/s}
# \end{equation*}
#
# Converting to m/day:
#
# \begin{equation*}
# K_{\mathrm{crude}}
# =0.10~\mathrm{m/day}
# \end{equation*}
#
# ##### Answer
# The hydraulic conductivities are approximately
#
# \begin{equation*}
# \boxed{K_{\mathrm{water}} = 0.70~\mathrm{m/day}}
# \end{equation*}
#
# \begin{equation*}
# \boxed{K_{\mathrm{gasoline}} = 0.87~\mathrm{m/day}}
# \end{equation*}
#
# \begin{equation*}
# \boxed{K_{\mathrm{crude}} = 0.10~\mathrm{m/day}}
# \end{equation*}
#
# The conductivity is highest for gasoline because of its relatively low viscosity and lowest for crude oil because of its much higher viscosity.
#
# :::

# %% [markdown]
# ### Question 11 - Falling head test

# %%
display_quiz("../quiz/2_SPF_PM/q_Falling_head.json")
# Out:
# <div id="IHIvwvhWnuCZ" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #IHIvwvhWnuCZ {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# ::::{hint} Hint Question 11
# :class: dropdown
# Derive the following equation: $\frac{dh}{dt} = -\frac{KA}{aL}h$. Can you do that? After you found out how to properly do this, you can solve this as a simple first order, linear ODE. Note $a$ is the diameter of the burette.
# :::{warning}
# There is no point just continuing without being able to derive the equation first. You need to understand its origin.
# :::
# ::::
#
# :::{tip} Solution Question 11
# :class: dropdown
#
# #### Step 1: Write the falling-head equation
#
# For a falling-head permeameter,
#
# \begin{equation*}
# K=\frac{aL}{At}\ln\left(\frac{h_1}{h_2}\right)
# \end{equation*}
#
# Rearranging to solve for time:
#
# \begin{equation*}
# t=\frac{aL}{AK}\ln\left(\frac{h_1}{h_2}\right)
# \end{equation*}
#
# where:
#
# - $a$ = cross-sectional area of the burette
# - $A$ = cross-sectional area of the sample
# - $L$ = sample length
# - $K$ = hydraulic conductivity
# - $h_1$ = initial head difference
# - $h_2$ = final head difference
#
# #### Step 2: Calculate the cross-sectional areas
#
# The sample diameter is
#
# \begin{equation*}
# D=8~\mathrm{cm}
# \end{equation*}
#
# Therefore,
#
# \begin{equation*}
# A=\frac{\pi D^2}{4}
# =\frac{\pi(8)^2}{4}
# =50.27~\mathrm{cm^2}
# \end{equation*}
#
# The burette diameter is
#
# \begin{equation*}
# d=2~\mathrm{mm}
# =0.2~\mathrm{cm}
# \end{equation*}
#
# Therefore,
#
# \begin{equation*}
# a=\frac{\pi d^2}{4}
# =\frac{\pi(0.2)^2}{4}
# =0.03142~\mathrm{cm^2}
# \end{equation*}
#
# #### Step 3: Substitute the known values
#
# The hydraulic conductivity is
#
# \begin{equation*}
# K=10^{-4}~\mathrm{cm/s}
# \end{equation*}
#
# The sample length is
#
# \begin{equation*}
# L=22~\mathrm{cm}
# \end{equation*}
#
# The head changes from
#
# \begin{equation*}
# h_1=80~\mathrm{cm}
# \end{equation*}
#
# to
#
# \begin{equation*}
# h_2=20~\mathrm{cm}
# \end{equation*}
#
# Thus,
#
# \begin{equation*}
# \ln\left(\frac{h_1}{h_2}\right)=\ln\left(\frac{80}{20}\right)=\ln(4)=1.3863
# \end{equation*}
#
# Substituting into the falling-head equation:
#
# \begin{equation*}
# t=\frac{(0.03142)(22)}{(50.27)(10^{-4})}\times 1.3863
# \end{equation*}
#
# \begin{equation*}
# t=190.8~\mathrm{s}
# \end{equation*}
#
# #### Answer
#
# \begin{equation*}
# \boxed{t \approx 191~\mathrm{s}}
# \end{equation*}
#
# or approximately
#
# \begin{equation*}
# \boxed{3.18~\mathrm{minutes}}
# \end{equation*}
#
# :::

# %% [markdown]
# ## Modeling
# ### Using a BTM
# Blabla
#
# ### Question X - Bundle of Tubes

# %%
import json
from jupyterquiz import display_quiz

display_quiz("../quiz/2_SPF_PM/q_psd_perm_cond.json")
# Out:
# <div id="xwxSjEawgfJu" data-shufflequestions="False" data-shuffleanswers="True" data-preserveresponses="false" data-numquestions="1000000" data-maxwidth="600" style="border-radius: 10px; text-align: left"><style>
# #xwxSjEawgfJu {
#    --jq-multiple-choice-bg: #6f78ffff;
#    --jq-mc-button-bg: #fafafa;
#    --jq-mc-button-border: #e0e0e0e0;
#    --jq-mc-button-inset-shadow: #555555;
#    --jq-many-choice-bg: #f75c03ff;
#    --jq-numeric-bg: #392061ff;
#    --jq-numeric-input-bg: #c0c0c0;
#    --jq-numeric-input-label: #101010;
#    --jq-numeric-input-shadow: #999999;
#    --jq-string-bg: #4c1a57;
#    --jq-incorrect-color: #c80202;
#    --jq-correct-color: #009113;
#    --jq-text-color: #fafafa;
# }
#
# .Quiz {
#     max-width: 600px;
#     margin-top: 15px;
#     margin-left: auto;
#     margin-right: auto;
# /*    margin-bottom: 15px;*/
# /*    padding-bottom: 4px;*/
#     padding-top: 4px;
#     line-height: 1.1;
#     font-size: 16pt;
#     border-radius: inherit;
# }
#
# ...

# %% [markdown]
# ::::{hint} Hint Question X
# :class: dropdown
#
# ::::
# :::{tip} Solution Question X
# :class: dropdown
# #### Part 1: Intrinsic Permeability Calculation
# We are given a parallel Bundle of Tubes model where the total void space ($\phi = 0.30$) is split equally between two pore radii fractions ($f_1 = 0.5$ and $f_2 = 0.5$):
# $$R_1 = 10 \times 10^{-6} \text{ m}$$
# $$R_2 = 20 \times 10^{-6} \text{ m}$$
#
# The governing equation derived from the Hagen-Poiseuille relationship for intrinsic permeability ($K$) of a parallel bundle of cylinders is:
# $$K = \frac{\phi}{8} \sum (f_i R_i^2)$$
#
# Substitute the known values into the summation:
# $$\sum (f_i R_i^2) = 0.5 \cdot (10 \times 10^{-6} \text{ m})^2 + 0.5 \cdot (20 \times 10^{-6} \text{ m})^2$$
# $$\sum (f_i R_i^2) = 0.5 \cdot (100 \times 10^{-12} \text{ m}^2) + 0.5 \cdot (400 \times 10^{-12} \text{ m}^2)$$
# $$\sum (f_i R_i^2) = (50 \times 10^{-12}) + (200 \times 10^{-12}) = 250 \times 10^{-12} \text{ m}^2$$
#
# Now, multiply by the porosity pre-factor:
# $$K = \frac{0.30}{8} \cdot (250 \times 10^{-12} \text{ m}^2)$$
# $$K = 0.0375 \cdot (250 \times 10^{-12} \text{ m}^2) = 9.375 \times 10^{-12} \text{ m}^2$$
#
# ---
#
# #### Part 2: Underlying Assumptions of Kozeny-Carman
# The classic Kozeny-Carman equation simplifies highly complex 3D porous structures into an equivalent hydraulic system. The core assumptions required to map a static, volumetric distribution directly to a dynamic permeability constant include:
#
# * **Non-Interacting Parallel Channels:** The system is treated as a continuous bundle of channels with a uniform mean hydraulic radius. It assumes the fluid moves evenly through these channels without crossing over or stalling.
# * **Neglecting Network Topology:** It ignores spatial bottlenecks (alternating expansions and contractions) and multi-directional routing loops (connectivity/coordination numbers).
# * **Laminar Viscous Flow:** It assumes creeping flow conditions ($\text{Re} < 1$), where Darcy's Law holds valid and inertial effects are non-existent.
# * **Isotropic Homogeneity:** The macroscopic properties are assumed to be evenly averaged across the sample continuum.
#
# :::

# %% [markdown]
# ### Using a PNM
# **Generating a network**<br>
#
#
# **Simulating single phase flow**<br>
#
#
# **Output**<br>

# %% [markdown]
# [Click here](/lite/notebooks/index.html?path=permeability_exercise.ipynb) for the full notebook experience

# %% [markdown]
# ## Permeability Exercise
#
# <iframe
#   src="../../lite/notebooks/index.html?path=permeability_exercise.ipynb"
#   width="100%"
#   height="80vh"
#   style="border:none;"
# ></iframe>

# %% [markdown]
# ## Interactive Exercise
#
# <iframe
#   src="../../lite/notebooks/index.html?path=porosity_exercise.ipynb"
#   width="100%"
#   height="80vh"
#   style="border:none;"
# ></iframe>

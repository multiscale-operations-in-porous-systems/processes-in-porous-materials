# %%
import numpy as np
import matplotlib.pyplot as plt
# BEFORE YOU RUN THE SCRIPT MAKE SURE YOU UNCOMMENT THE CODE.
# 1. Create an array of values for e (from 0 to 3 with steps of 0.1)
#e = ...

# 2. Calculate the corresponding values of \phi
#phi = ...

# 3. Plot \phi versus e
#plt.plot(...)

# 4. Label the axes and add a title
#plt.xlabel(...)
#plt.ylabel(...)
#plt.title(...)
#plt.grid(...)
#plt.show()
